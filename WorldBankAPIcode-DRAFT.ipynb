# %%
# Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
from pprint import pprint

url = "https://api.worldbank.org/countries/indicators/HD.HCI.OVRL?per_page=100&date=2000:2015&format=json"

# %%
response = requests.get(url)
raw_data = response.json()
countries = raw_data[1][0]['country']['value']
print(countries)
# Out:
# Afghanistan

# %%
len(raw_data[1])
# Out:
# 100

# %%
# Report the names
countries = []
gdp =[]

for i in range(len(raw_data[1])):
    countries.append(raw_data[1][i]['country']['value'])

# %%
# Out:
# ['Euro Area',
#  'Euro Area',
#  'Euro Area',
#  'Euro Area',
#  'Euro Area',
#  'Euro Area',
#  'Euro Area',
#  'Euro Area',
#  'Euro Area',
#  'Euro Area',
#  'Euro Area',
#  'Euro Area',
#  'Euro Area',
#  'Euro Area',
#  'Euro Area',
#  'Euro Area',
#  'Euro Area',
#  'Euro Area',
#  'Euro Area',
#  'Euro Area',
#  'Euro Area',
#  'Euro Area',
#  'Euro Area',
#  'Advanced economies',
#  'Advanced economies',
#  'Advanced economies',
#  'Advanced economies',
#  'Advanced economies',
#  'Advanced economies',
#  'Advanced economies',
#  'Advanced economies',
#  'Advanced economies',
#  'Advanced economies',
#  'Advanced economies',
#  'Advanced economies',
#  'Advanced economies',
#  'Advanced economies',
#  'Advanced economies',
#  'Advanced economies',
#  'Advanced economies',
#  'Advanced economies',
#  'Advanced economies',
#  'Advanced economies',
#  'Advanced economies',
#  'Advanced economies',
#  'Advanced economies',
#  'East Asia and Pacific',
#  'East Asia and Pacific',
# ...

# %%
pprint(response.json())
# Out:
# [{'page': 1, 'pages': 2, 'per_page': '100', 'total': 157},
#  [{'country': {'id': 'AF', 'value': 'Afghanistan'},
#    'date': '2017',
#    'decimal': '1',
#    'indicator': {'id': 'HD.HCI.OVRL',
#                  'value': 'Human Capital Index (HCI) (scale 0-1)'},
#    'value': '0.389'},
#   {'country': {'id': 'AL', 'value': 'Albania'},
#    'date': '2017',
#    'decimal': '1',
#    'indicator': {'id': 'HD.HCI.OVRL',
#                  'value': 'Human Capital Index (HCI) (scale 0-1)'},
#    'value': '0.621'},
#   {'country': {'id': 'DZ', 'value': 'Algeria'},
#    'date': '2017',
#    'decimal': '1',
#    'indicator': {'id': 'HD.HCI.OVRL',
#                  'value': 'Human Capital Index (HCI) (scale 0-1)'},
#    'value': '0.523'},
#   {'country': {'id': 'AO', 'value': 'Angola'},
#    'date': '2017',
#    'decimal': '1',
#    'indicator': {'id': 'HD.HCI.OVRL',
#                  'value': 'Human Capital Index (HCI) (scale 0-1)'},
#    'value': '0.361'},
# ...

# %%
len(raw_data)
# Out:
# 2

# %%
df = pd.DataFrame(raw_data[1])

# %%
df.columns
# Out:
# Index(['country', 'date', 'decimal', 'indicator', 'value'], dtype='object')

# %%
df['country'].value_counts()
# Out:
# {'id': 'EA', 'value': 'Euro Area'}                        23
# {'id': '', 'value': 'East Asia and Pacific'}              23
# {'id': '', 'value': 'Advanced economies'}                 23
# {'id': '', 'value': 'Europe and Central Asia'}            23
# {'id': '', 'value': 'Latin America and the Caribbean'}     8
# Name: country, dtype: int64

# %%
df.head()
# Out:
#                               country  date decimal  \
# 0  {'id': 'EA', 'value': 'Euro Area'}  2021       1
# 1  {'id': 'EA', 'value': 'Euro Area'}  2020       1
# 2  {'id': 'EA', 'value': 'Euro Area'}  2019       1
# 3  {'id': 'EA', 'value': 'Euro Area'}  2018       1
# 4  {'id': 'EA', 'value': 'Euro Area'}  2017       1
#
#                                            indicator value
# 0  {'id': 'NYGDPMKTPKDZ', 'value': 'GDP growth, c...   1.3
# 1  {'id': 'NYGDPMKTPKDZ', 'value': 'GDP growth, c...   1.5
# 2  {'id': 'NYGDPMKTPKDZ', 'value': 'GDP growth, c...   1.6
# 3  {'id': 'NYGDPMKTPKDZ', 'value': 'GDP growth, c...   1.9
# 4  {'id': 'NYGDPMKTPKDZ', 'value': 'GDP growth, c...   2.4

# %%
pd.DataFrame({'country':countries})
# Out:
#                    country
# 0              Afghanistan
# 1                  Albania
# 2                  Algeria
# 3                   Angola
# 4                Argentina
# 5                  Armenia
# 6                Australia
# 7                  Austria
# 8               Azerbaijan
# 9                  Bahrain
# 10              Bangladesh
# 11                 Belgium
# 12                   Benin
# 13  Bosnia and Herzegovina
# 14                Botswana
# 15                  Brazil
# 16                Bulgaria
# 17            Burkina Faso
# 18                 Burundi
# 19                Cambodia
# 20                Cameroon
# 21                  Canada
# 22                    Chad
# 23                   Chile
# 24                   China
# 25                Colombia
# 26                 Comoros
# 27        Congo, Dem. Rep.
# 28             Congo, Rep.
# 29              Costa Rica
# ..                     ...
# 70                Kiribati
# 71             Korea, Rep.
# ...
