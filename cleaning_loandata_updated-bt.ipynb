# %%
import pandas as pd
import numpy as np

# %%
loan_data=pd.read_csv('kiva_loans.csv')

# %%
loan_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 671205 entries, 0 to 671204
# Data columns (total 20 columns):
# id                    671205 non-null int64
# funded_amount         671205 non-null float64
# loan_amount           671205 non-null float64
# activity              671205 non-null object
# sector                671205 non-null object
# use                   666973 non-null object
# country_code          671197 non-null object
# country               671205 non-null object
# region                614405 non-null object
# currency              671205 non-null object
# partner_id            657698 non-null float64
# posted_time           671205 non-null object
# disbursed_time        668809 non-null object
# funded_time           622874 non-null object
# term_in_months        671205 non-null float64
# lender_count          671205 non-null int64
# tags                  499789 non-null object
# borrower_genders      666984 non-null object
# ...

# %%
loan_data.head()
# Out:
#        id  funded_amount  loan_amount             activity          sector  \
# 0  653051          300.0        300.0  Fruits & Vegetables            Food
# 1  653053          575.0        575.0             Rickshaw  Transportation
# 2  653068          150.0        150.0       Transportation  Transportation
# 3  653063          200.0        200.0           Embroidery            Arts
# 4  653084          400.0        400.0           Milk Sales            Food
#
#                                                  use country_code   country  \
# 0            To buy seasonal, fresh fruits to sell.            PK  Pakistan
# 1  to repair and maintain the auto rickshaw used ...           PK  Pakistan
# 2  To repair their old cycle-van and buy another ...           IN     India
# 3  to purchase an embroidery machine and a variet...           PK  Pakistan
# 4                           to purchase one buffalo.           PK  Pakistan
#
# ...

# %%
# Change date time datetype from string to datetime

# %%
loan_data['postedtime']=pd.to_datetime(loan_data['posted_time'])
loan_data['disbursedtime']=pd.to_datetime(loan_data['disbursed_time'])
loan_data['fundedtime']=pd.to_datetime(loan_data['funded_time'])

# %%
loan_data.head()
# Out:
#        id  funded_amount  loan_amount             activity          sector  \
# 0  653051          300.0        300.0  Fruits & Vegetables            Food
# 1  653053          575.0        575.0             Rickshaw  Transportation
# 2  653068          150.0        150.0       Transportation  Transportation
# 3  653063          200.0        200.0           Embroidery            Arts
# 4  653084          400.0        400.0           Milk Sales            Food
#
#                                                  use country_code   country  \
# 0            To buy seasonal, fresh fruits to sell.            PK  Pakistan
# 1  to repair and maintain the auto rickshaw used ...           PK  Pakistan
# 2  To repair their old cycle-van and buy another ...           IN     India
# 3  to purchase an embroidery machine and a variet...           PK  Pakistan
# 4                           to purchase one buffalo.           PK  Pakistan
#
# ...

# %%
loan_data['borrower_genders'].unique()
# Out:
# array(['female', 'female, female', 'female, female, female', ...,
#        'female, female, male, female, female, female, female, female, female, female, male, male, female, female, male, female, female, female, female, female, female, female',
#        'male, female, female, female, female, female, female, female, male, male, female, male, female, male, male, male',
#        'female, female, female, male, female, female, female, male, female, female, female, male, female, male, female, female, female, female, female, female, female, female, female, female, female, female, female, female, male'], dtype=object)

# %%
# Clean up the gender column

# %%
loan_data['borrowergenders']=loan_data['borrower_genders'].str.split(',').str[0]

# %%
loan_data.head()
# Out:
#        id  funded_amount  loan_amount             activity          sector  \
# 0  653051          300.0        300.0  Fruits & Vegetables            Food
# 1  653053          575.0        575.0             Rickshaw  Transportation
# 2  653068          150.0        150.0       Transportation  Transportation
# 3  653063          200.0        200.0           Embroidery            Arts
# 4  653084          400.0        400.0           Milk Sales            Food
#
#                                                  use country_code   country  \
# 0            To buy seasonal, fresh fruits to sell.            PK  Pakistan
# 1  to repair and maintain the auto rickshaw used ...           PK  Pakistan
# 2  To repair their old cycle-van and buy another ...           IN     India
# 3  to purchase an embroidery machine and a variet...           PK  Pakistan
# 4                           to purchase one buffalo.           PK  Pakistan
#
# ...

# %%
loan_data['tags'].unique()
# Out:
# array([nan, 'user_favorite, user_favorite', '#Elderly, #Woman Owned Biz',
#        ..., 'user_favorite, #Biz Durable Asset, #Single, #Trees, #Vegan',
#        'user_favorite, user_favorite, #Parent, #Repair Renew Replace, #Vegan, user_favorite, user_favorite',
#        'user_favorite, #Parent, #Biz Durable Asset, #Vegan, user_favorite'], dtype=object)

# %%
loan_data['sector'].unique()
# Out:
# array(['Food', 'Transportation', 'Arts', 'Services', 'Agriculture',
#        'Manufacturing', 'Wholesale', 'Retail', 'Clothing', 'Construction',
#        'Health', 'Education', 'Personal Use', 'Housing', 'Entertainment'], dtype=object)

# %%
loan_data['use'].unique()
# Out:
# array(['To buy seasonal, fresh fruits to sell. ',
#        'to repair and maintain the auto rickshaw used in their business.',
#        'To repair their old cycle-van and buy another one to rent out as a source of income',
#        ...,
#        'Pretend the issue with loan got addressed by Kiva Coordinator.',
#        'Kiva Coordinator replaced loan use. Should see this in viewdiff.',
#        'Edited loan use in english.'], dtype=object)

# %%
loan_data['use'].nunique()
# Out:
# 424912

# %%
loan_data['currency'].unique()
# Out:
# array(['PKR', 'INR', 'KES', 'NIO', 'USD', 'TZS', 'PHP', 'PEN', 'XOF',
#        'LRD', 'VND', 'HNL', 'MNT', 'COP', 'GTQ', 'TJS', 'BOB', 'YER',
#        'KHR', 'GHS', 'SLL', 'HTG', 'CLP', 'JOD', 'UGX', 'BIF', 'IDR',
#        'GEL', 'UAH', 'EUR', 'ALL', 'CRC', 'XAF', 'TRY', 'AZN', 'DOP',
#        'BRL', 'MXN', 'KGS', 'AMD', 'PYG', 'LBP', 'WST', 'ILS', 'RWF',
#        'ZMW', 'NPR', 'MZN', 'ZAR', 'BZD', 'SRD', 'NGN', 'VUV', 'XCD',
#        'MWK', 'LAK', 'MMK', 'ZWD', 'MDL', 'SSP', 'SBD', 'CNY', 'EGP',
#        'MGA', 'NAD', 'LSL', 'THB'], dtype=object)

# %%
loan_data['loan_amount'].isnull().sum()
# Out:
# 0

# %%
loan_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 671205 entries, 0 to 671204
# Data columns (total 24 columns):
# id                    671205 non-null int64
# funded_amount         671205 non-null float64
# loan_amount           671205 non-null float64
# activity              671205 non-null object
# sector                671205 non-null object
# use                   666973 non-null object
# country_code          671197 non-null object
# country               671205 non-null object
# region                614405 non-null object
# currency              671205 non-null object
# partner_id            657698 non-null float64
# posted_time           671205 non-null object
# disbursed_time        668809 non-null object
# funded_time           622874 non-null object
# term_in_months        671205 non-null float64
# lender_count          671205 non-null int64
# tags                  499789 non-null object
# borrower_genders      666984 non-null object
# ...

# %%
loan_data.head()
# Out:
#        id  funded_amount  loan_amount             activity          sector  \
# 0  653051          300.0        300.0  Fruits & Vegetables            Food
# 1  653053          575.0        575.0             Rickshaw  Transportation
# 2  653068          150.0        150.0       Transportation  Transportation
# 3  653063          200.0        200.0           Embroidery            Arts
# 4  653084          400.0        400.0           Milk Sales            Food
#
#                                                  use country_code   country  \
# 0            To buy seasonal, fresh fruits to sell.            PK  Pakistan
# 1  to repair and maintain the auto rickshaw used ...           PK  Pakistan
# 2  To repair their old cycle-van and buy another ...           IN     India
# 3  to purchase an embroidery machine and a variet...           PK  Pakistan
# 4                           to purchase one buffalo.           PK  Pakistan
#
# ...

# %%
loan_new=loan_data.drop(columns=['activity','use','tags','borrower_genders','posted_time','disbursed_time','date','funded_time','repayment_interval'])

# %%
loan_new.head()
# Out:
#        id  funded_amount  loan_amount          sector country_code   country  \
# 0  653051          300.0        300.0            Food           PK  Pakistan
# 1  653053          575.0        575.0  Transportation           PK  Pakistan
# 2  653068          150.0        150.0  Transportation           IN     India
# 3  653063          200.0        200.0            Arts           PK  Pakistan
# 4  653084          400.0        400.0            Food           PK  Pakistan
#
#          region currency  partner_id  term_in_months  lender_count  \
# 0        Lahore      PKR       247.0            12.0            12
# 1        Lahore      PKR       247.0            11.0            14
# 2     Maynaguri      INR       334.0            43.0             6
# 3        Lahore      PKR       247.0            11.0             8
# 4  Abdul Hakeem      PKR       245.0            14.0            16
#
#            postedtime       disbursedtime          fundedtime borrowergenders
# ...

# %%
loan_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 671205 entries, 0 to 671204
# Data columns (total 15 columns):
# id                 671205 non-null int64
# funded_amount      671205 non-null float64
# loan_amount        671205 non-null float64
# sector             671205 non-null object
# country_code       671197 non-null object
# country            671205 non-null object
# region             614405 non-null object
# currency           671205 non-null object
# partner_id         657698 non-null float64
# term_in_months     671205 non-null float64
# lender_count       671205 non-null int64
# postedtime         671205 non-null datetime64[ns]
# disbursedtime      668809 non-null datetime64[ns]
# fundedtime         622874 non-null datetime64[ns]
# borrowergenders    666984 non-null object
# dtypes: datetime64[ns](3), float64(4), int64(2), object(6)
# memory usage: 76.8+ MB

# %%
loan_new=loan_new.dropna()

# %%
loan_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 574119 entries, 0 to 671186
# Data columns (total 15 columns):
# id                 574119 non-null int64
# funded_amount      574119 non-null float64
# loan_amount        574119 non-null float64
# sector             574119 non-null object
# country_code       574119 non-null object
# country            574119 non-null object
# region             574119 non-null object
# currency           574119 non-null object
# partner_id         574119 non-null float64
# term_in_months     574119 non-null float64
# lender_count       574119 non-null int64
# postedtime         574119 non-null datetime64[ns]
# disbursedtime      574119 non-null datetime64[ns]
# fundedtime         574119 non-null datetime64[ns]
# borrowergenders    574119 non-null object
# dtypes: datetime64[ns](3), float64(4), int64(2), object(6)
# memory usage: 70.1+ MB

# %%
loan_new.to_csv('loan_clean.csv')

# %%
loan_new.duplicated().sum()
# Out:
# 0
