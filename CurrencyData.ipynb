# %%
import requests
import json
import pandas as pd

# %%
from apiExchange import api_key

# %%
CPI_Data = pd.read_csv("CorruptionPerceptionIndex.csv")
CPI_Data.head()
# Out:
#        Country ISO3 Region  CPI score 2018  Rank 2018  Sources 2018  \
# 0      Denmark  DNK  WE/EU              88          1             8
# 1  New Zealand  NZL     AP              87          2             8
# 2      Finland  FIN  WE/EU              85          3             8
# 3    Singapore  SGP     AP              85          3             9
# 4       Sweden  SWE  WE/EU              85          3             8
#
#    Standard error 2018  CPI score 2017  Rank 2017  Sources 2017  \
# 0                 2.63              88          2             8
# 1                 2.44              89          1             8
# 2                 2.74              85          3             8
# 3                 1.98              84          6             9
# 4                 2.02              84          6             8
#
#           ...           Standard error 2015  CPI score 2014  Sources 2014  \
# 0         ...                          2.16            92.0           7.0
# ...

# %%
CPI_Data["Currency ID"] = ""
CPI_Data["Currency Value in USD"] = ""
USD = "USD_"
base_url="https://free.currencyconverterapi.com/api/v6/currencies?apiKey=" + api_key
CPI_Data.head()
# Out:
#        Country ISO3 Region  CPI score 2018  Rank 2018  Sources 2018  \
# 0      Denmark  DNK  WE/EU              88          1             8
# 1  New Zealand  NZL     AP              87          2             8
# 2      Finland  FIN  WE/EU              85          3             8
# 3    Singapore  SGP     AP              85          3             9
# 4       Sweden  SWE  WE/EU              85          3             8
#
#    Standard error 2018  CPI score 2017  Rank 2017  Sources 2017  \
# 0                 2.63              88          2             8
# 1                 2.44              89          1             8
# 2                 2.74              85          3             8
# 3                 1.98              84          6             9
# 4                 2.02              84          6             8
#
#            ...            Sources 2014  Standard error 2014  CPI Score 2013  \
# 0          ...                     7.0                 2.04            91.0
# ...

# %%
for index, row in CPI_Data.iterrows():
    #get country from df
    country = row["Country"]
    query_url = base_url
 
    response = requests.get(query_url).json()
    results = response

# %%
https://free.currencyconverterapi.com
    currencyId
