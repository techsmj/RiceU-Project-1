# %%
import pandas as pd

# %%
MasterData = pd.read_csv('MasterDataSet_updated.csv')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-6-29aa1628b8bc> in <module>
# ----> 1 MasterData = pd.read_csv('MasterDataSet_updated.csv')
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
# ...

# %%
MasterData.head()

# %%
#drop extra rate column
MasterData.drop(['Rate in USD_y'], inplace=True, axis=1)
MasterData.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1      id  funded_amount  loan_amount country_code  \
# 0           0             1  653053          575.0        575.0           PK
# 1           1             3  653063          200.0        200.0           PK
# 2           2             4  653084          400.0        400.0           PK
# 3           3             7  653078          400.0        400.0           PK
# 4           4             8  653082          475.0        475.0           PK
#
#     Country currency  partner_id  lender_count           fundedtime  \
# 0  Pakistan      PKR       247.0            14  2014-01-02 09:17:23
# 1  Pakistan      PKR       247.0             8  2014-01-01 13:00:00
# 2  Pakistan      PKR       245.0            16  2014-01-01 19:18:51
# 3  Pakistan      PKR       245.0             8  2014-01-10 18:18:44
# 4  Pakistan      PKR       245.0            19  2014-01-01 18:47:21
#
#   borrowergenders ISO3  CPI score 2017  CPI score 2014  Rate in USD_x  \
# ...

# %%
#add column to convert loan amount to USD
MasterData["Loan amount in USD"]=MasterData['loan_amount']/MasterData['Rate in USD_x']
MasterData.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1      id  funded_amount  loan_amount country_code  \
# 0           0             1  653053          575.0        575.0           PK
# 1           1             3  653063          200.0        200.0           PK
# 2           2             4  653084          400.0        400.0           PK
# 3           3             7  653078          400.0        400.0           PK
# 4           4             8  653082          475.0        475.0           PK
#
#     Country currency  partner_id  lender_count           fundedtime  \
# 0  Pakistan      PKR       247.0            14  2014-01-02 09:17:23
# 1  Pakistan      PKR       247.0             8  2014-01-01 13:00:00
# 2  Pakistan      PKR       245.0            16  2014-01-01 19:18:51
# 3  Pakistan      PKR       245.0             8  2014-01-10 18:18:44
# 4  Pakistan      PKR       245.0            19  2014-01-01 18:47:21
#
#   borrowergenders ISO3  CPI score 2017  CPI score 2014  Rate in USD_x  \
# ...

# %%
MasterData.to_csv('FinalDataSet.csv')
