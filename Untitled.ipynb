# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
import json

# %%
data = pd.read_csv('Final_table1.csv', low_memory=False)

# %%
data.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1      id  funded_amount  loan_amount country_code  \
# 0           0             0  653053          575.0        575.0           PK
# 1           1             1  653053          575.0        575.0           PK
# 2           2             2  653053          575.0        575.0           PK
# 3           3             3  653053          575.0        575.0           PK
# 4           4             4  653053          575.0        575.0           PK
#
#     Country currency  partner_id  lender_count  \
# 0  Pakistan      PKR       247.0            14
# 1  Pakistan      PKR       247.0            14
# 2  Pakistan      PKR       247.0            14
# 3  Pakistan      PKR       247.0            14
# 4  Pakistan      PKR       247.0            14
#
#                     ...                                region world_region  \
# 0                   ...                                Punjab   South Asia
# 1                   ...                                 Sindh   South Asia
# 2                   ...                    Khyber Pakhtunkhwa   South Asia
# 3                   ...                           Balochistan   South Asia
# 4                   ...                      Gilgit Baltistan   South Asia
#
#      MPI                              geo        lat        lon Country Code  \
# 0  0.184         (31.1704063, 72.7097161)  31.170406  72.709716          PAK
# 1  0.294  (25.8943018, 68.52471489999999)  25.894302  68.524715          PAK
# 2  0.247          (34.9526205, 72.331113)  34.952621  72.331113          PAK
# 3  0.402         (28.4907332, 65.0957792)  28.490733  65.095779          PAK
# 4  0.233  (35.80256670000001, 74.9831808)  35.802567  74.983181          PAK
#
#   % of Rural Pop.  GDP Per Capita  Dom. Credit to Prvt Sector as % of GDP
# 0          60.776     1547.853414                               16.509756
# 1          60.776     1547.853414                               16.509756
# 2          60.776     1547.853414                               16.509756
# 3          60.776     1547.853414                               16.509756
# 4          60.776     1547.853414                               16.509756
#
# [5 rows x 32 columns]

# %%
list(data)
# Out:
# ['Unnamed: 0',
#  'Unnamed: 0.1',
#  'id',
#  'funded_amount',
#  'loan_amount',
#  'country_code',
#  'Country',
#  'currency',
#  'partner_id',
#  'lender_count',
#  'fundedtime',
#  'borrowergenders',
#  'ISO3',
#  'CPI score 2017',
#  'CPI score 2014',
#  'Rate in USD_x',
#  'Continent_Name',
#  'Loan Theme Type',
#  'Loan amount in USD',
#  'index',
#  'LocationName',
#  'ISO',
#  'region',
#  'world_region',
#  'MPI',
#  'geo',
#  'lat',
#  'lon',
#  'Country Code',
#  '% of Rural Pop.',
#  'GDP Per Capita',
#  'Dom. Credit to Prvt Sector as % of GDP']

# %%
result_df = data.drop_duplicates(subset=['id'], keep='first')

# %%
result_df.head()
# Out:
#     Unnamed: 0  Unnamed: 0.1      id  funded_amount  loan_amount country_code  \
# 0            0             0  653053          575.0        575.0           PK
# 6            6             6  653063          200.0        200.0           PK
# 12          12            12  653084          400.0        400.0           PK
# 18          18            18  653078          400.0        400.0           PK
# 24          24            24  653082          475.0        475.0           PK
#
#      Country currency  partner_id  lender_count  \
# 0   Pakistan      PKR       247.0            14
# 6   Pakistan      PKR       247.0             8
# 12  Pakistan      PKR       245.0            16
# 18  Pakistan      PKR       245.0             8
# 24  Pakistan      PKR       245.0            19
#
#                      ...                    region world_region    MPI  \
# 0                    ...                    Punjab   South Asia  0.184
# 6                    ...                    Punjab   South Asia  0.184
# 12                   ...                    Punjab   South Asia  0.184
# 18                   ...                    Punjab   South Asia  0.184
# 24                   ...                    Punjab   South Asia  0.184
#
#                          geo        lat        lon Country Code  \
# 0   (31.1704063, 72.7097161)  31.170406  72.709716          PAK
# 6   (31.1704063, 72.7097161)  31.170406  72.709716          PAK
# 12  (31.1704063, 72.7097161)  31.170406  72.709716          PAK
# 18  (31.1704063, 72.7097161)  31.170406  72.709716          PAK
# 24  (31.1704063, 72.7097161)  31.170406  72.709716          PAK
#
#    % of Rural Pop.  GDP Per Capita  Dom. Credit to Prvt Sector as % of GDP
# 0           60.776     1547.853414                               16.509756
# 6           60.776     1547.853414                               16.509756
# 12          60.776     1547.853414                               16.509756
# 18          60.776     1547.853414                               16.509756
# 24          60.776     1547.853414                               16.509756
#
# [5 rows x 32 columns]

# %%
highest_Continent_group = result_df.groupby(['world_region']).agg({'borrowergenders' :"count"})



#Gender_group.reset_index()

highest_Continent_group.apply(pd.Series)
highest_Continent_group
# Out:
#                              borrowergenders
# world_region
# Arab States                             3877
# East Asia and the Pacific             196694
# Europe and Central Asia                28064
# Latin America and Caribbean            80369
# South Asia                             36500
# Sub-Saharan Africa                    124697

# %%
Gender_group = result_df.groupby(["borrowergenders", 'world_region']).agg({'world_region' :"count"})

#Gender_group.reset_index()

Gender_group.apply(pd.Series)
Gender_group.rename(columns= {"world_region":"Total"})
Gender_group
# Out:
#                                              world_region
# borrowergenders world_region
# female          Arab States                          2560
#                 East Asia and the Pacific          181526
#                 Europe and Central Asia             19855
#                 Latin America and Caribbean         51725
#                 South Asia                          35537
#                 Sub-Saharan Africa                  84908
# male            Arab States                          1317
#                 East Asia and the Pacific           15168
#                 Europe and Central Asia              8209
#                 Latin America and Caribbean         28644
#                 South Asia                            963
#                 Sub-Saharan Africa                  39789

# %%
renamedf = Gender_group.rename(columns= {"world_region":"Total"})
renamedf
# Out:
#                                               Total
# borrowergenders world_region
# female          Arab States                    2560
#                 East Asia and the Pacific    181526
#                 Europe and Central Asia       19855
#                 Latin America and Caribbean   51725
#                 South Asia                    35537
#                 Sub-Saharan Africa            84908
# male            Arab States                    1317
#                 East Asia and the Pacific     15168
#                 Europe and Central Asia        8209
#                 Latin America and Caribbean   28644
#                 South Asia                      963
#                 Sub-Saharan Africa            39789

# %%
groupdf= renamedf.pivot_table(index=['world_region'], columns='borrowergenders', values='Total', fill_value='').rename_axis('', axis=1).reset_index()
        
#groupdf= groupdf.set_index('Continent')
groupdf.rename(columns= {"world_region":"World Region"})
# Preview that Reformatting worked
groupdf
# Out:
#                   world_region  female   male
# 0                  Arab States    2560   1317
# 1    East Asia and the Pacific  181526  15168
# 2      Europe and Central Asia   19855   8209
# 3  Latin America and Caribbean   51725  28644
# 4                   South Asia   35537    963
# 5           Sub-Saharan Africa   84908  39789

# %%
groupdf.rename(columns= {"world_region":"World Region"})
# Out:
#                   World Region  female   male
# 0                  Arab States    2560   1317
# 1    East Asia and the Pacific  181526  15168
# 2      Europe and Central Asia   19855   8209
# 3  Latin America and Caribbean   51725  28644
# 4                   South Asia   35537    963
# 5           Sub-Saharan Africa   84908  39789

# %%
y = groupdf['female']
z=groupdf['male']



ind = np.arange(len(y))  # the x locations for the groups
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(ind - width/2, y, width, color='SkyBlue', label='Women')
rects2 = ax.bar(ind + width/2, z, width, color='IndianRed', label='Men')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Total Number')
ax.set_title('Continent by gender')
ax.set_xticks(ind)
ax.set_xticklabels(('Arab States', 'East Asia and the Pacific', 'Europe and Central Asia', 'Latin America and Caribbean', 'South Asia','Sub-Saharan Africa'))
ax.legend()
plt.xticks(rotation=45)


                   
plt.show()

# %%
result_df['Country'].unique()
# Out:
# array(['Pakistan', 'India', 'Kenya', 'Nicaragua', 'Philippines', 'Peru',
#        'Cambodia', 'Liberia', 'Honduras', 'Mongolia', 'Mali', 'Colombia',
#        'Tajikistan', 'El Salvador', 'Ghana', 'Sierra Leone', 'Haiti',
#        'Senegal', 'Jordan', 'Uganda', 'Burundi', 'Burkina Faso',
#        'Indonesia', 'Ukraine', 'Albania', 'Somalia', 'Cameroon',
#        'Dominican Republic', 'Brazil', 'Mexico', 'Azerbaijan', 'Armenia',
#        'Zambia', 'Nepal', 'Mozambique', 'South Africa', 'Togo', 'Rwanda',
#        'Suriname', 'Thailand', 'Nigeria', 'Mauritania', 'Vanuatu',
#        'Malawi', 'Benin', 'South Sudan', 'China', 'Afghanistan',
#        'Lesotho', 'Bhutan'], dtype=object)

# %%
Gender_group1 = result_df.groupby(["borrowergenders", "world_region",'Country']).agg({'loan_amount' :"sum"})

#Gender_group.reset_index()

Gender_group1.apply(pd.Series)
Gender_group1.rename(columns= {"Country":"Total"})
Gender_group1
# Out:
#                                                                 loan_amount
# borrowergenders world_region                Country
# female          Arab States                 Jordan                2856575.0
#                                             Somalia                122600.0
#                 East Asia and the Pacific   Cambodia             15511575.0
#                                             China                  107875.0
#                                             Indonesia             2532600.0
#                                             Mongolia               720375.0
#                                             Philippines          50239225.0
#                                             Thailand               249500.0
#                                             Vanuatu                  6700.0
#                 Europe and Central Asia     Albania                967925.0
#                                             Armenia               6984875.0
#                                             Azerbaijan            1090625.0
#                                             Tajikistan            9541425.0
#                                             Ukraine                884000.0
#                 Latin America and Caribbean Brazil                 456800.0
#                                             Colombia              6534000.0
#                                             Dominican Republic    1504825.0
#                                             El Salvador           6214575.0
#                                             Haiti                 1796350.0
#                                             Honduras              3161625.0
#                                             Mexico                6059675.0
#                                             Nicaragua             6347375.0
#                                             Peru                 21270250.0
#                                             Suriname                40325.0
#                 South Asia                  Afghanistan             14000.0
#                                             Bhutan                  10000.0
#                                             India                 5843600.0
#                                             Nepal                  287500.0
#                                             Pakistan             10791975.0
#                 Sub-Saharan Africa          Burkina Faso          2267675.0
# ...                                                                     ...
# male            Latin America and Caribbean Haiti                  748425.0
#                                             Honduras              2101450.0
#                                             Mexico                2571125.0
#                                             Nicaragua             2179175.0
#                                             Peru                  8438000.0
#                                             Suriname               460200.0
#                 South Asia                  India                  160275.0
#                                             Nepal                   20125.0
#                                             Pakistan               974725.0
#                 Sub-Saharan Africa          Benin                   50300.0
#                                             Burkina Faso           613625.0
#                                             Burundi                665725.0
#                                             Cameroon               188750.0
#                                             Ghana                  769200.0
#                                             Kenya                 8529175.0
#                                             Lesotho                 55250.0
#                                             Liberia                 90350.0
#                                             Malawi                 167050.0
#                                             Mali                  2042600.0
#                                             Mauritania              15000.0
#                                             Mozambique             736950.0
#                                             Nigeria               1466250.0
#                                             Rwanda                 537600.0
#                                             Senegal                 29300.0
#                                             Sierra Leone           724925.0
#                                             South Africa           240150.0
#                                             South Sudan             30975.0
#                                             Togo                   152175.0
#                                             Uganda                7077225.0
#                                             Zambia                 555500.0
#
# [96 rows x 1 columns]
